# %%
import warnings
warnings.filterwarnings("ignore")

from transformers import AutoTokenizer, AutoModelForCausalLM
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

w
with open("sonnets.txt", "r") as file:
    sonnets_text = file.read()

sonnets = [sonnet.strip() for sonnet in sonnets_text.split('\n\n') if sonnet.strip()]
sonnets = sonnets[:20]

prompts = [sonnet.split('\n')[0] for sonnet in sonnets]
original_sonnets = sonnets

print("\n=== Prompts (First Lines of Each Sonnet) ===")
for i, prompt in enumerate(prompts, 1):
    print(f"Prompt {i}: {prompt}")
print("\n")


model_name = "ayazfau/GPT2-124M-poetry-RL"
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name).eval()
except Exception as e:
    print(f"Error loading model: {e}")
    exit()


if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id


def generate_verse(prompt, max_length=200, temperature=0.8, top_k=40, top_p=0.95):
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        padding=True,
        return_attention_mask=True
    )
    outputs = model.generate(
        input_ids=inputs['input_ids'],
        attention_mask=inputs['attention_mask'],
        max_length=max_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        num_return_sequences=1,
        pad_token_id=tokenizer.pad_token_id,
        no_repeat_ngram_size=2,
        do_sample=True
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)


generated_sonnets = []
bleu_scores = []
smoothie = SmoothingFunction().method4

for prompt, original in zip(prompts, original_sonnets):
    generated_verse = generate_verse(prompt)
    generated_sonnets.append(generated_verse)

    reference = [original.split()]
    candidate = generated_verse.split()
    score = sentence_bleu(reference, candidate, smoothing_function=smoothie)
    bleu_scores.append(score)


print("=== Final Comparison: Original vs. Generated Sonnets ===")
for i, (original, generated, score) in enumerate(zip(original_sonnets, generated_sonnets, bleu_scores), 1):
    print(f"\nSonnet {i}:")
    print("Original:")
    print(original.replace('\n', '\n  '))
    print("\nGenerated:")
    print(generated.replace('\n', '\n  '))
    print(f"\nBLEU Score: {score:.4f}")

print(f"\nAverage BLEU: {sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0:.4f}")
# Out:
# === Prompts (First Lines of Each Sonnet) ===
# Prompt 1: FROM fairest creatures we desire increase,
# Prompt 2: When forty winters shall beseige thy brow,
# Prompt 3: Look in thy glass, and tell the face thou viewest
# Prompt 4: Unthrifty loveliness, why dost thou spend
# Prompt 5: Those hours, that with gentle work did frame
# Prompt 6: Then let not winter's ragged hand deface
# Prompt 7: Lo! in the orient when the gracious light
# Prompt 8: Music to hear, why hear'st thou music sadly?
# Prompt 9: Is it for fear to wet a widow's eye
# Prompt 10: For shame! deny that thou bear'st love to any,
# Prompt 11: As fast as thou shalt wane, so fast thou growest
# Prompt 12: When I do count the clock that tells the time,
# Prompt 13: O, that you were yourself! but, love, you are
# Prompt 14: Not from the stars do I my judgment pluck;
# Prompt 15: When I consider every thing that grows
# Prompt 16: But wherefore do not you a mightier way
# Prompt 17: Who will believe my verse in time to come,
# Prompt 18: Shall I compare thee to a summer's day?
# Prompt 19: Devouring Time, blunt thou the lion's paws,
# Prompt 20: A woman's face with Nature's own hand painted
#
#
# === Final Comparison: Original vs. Generated Sonnets ===
#
# Sonnet 1:
# Original:
# FROM fairest creatures we desire increase,
#   That thereby beauty's rose might never die,
#   But as the riper should by time decease,
#   His tender heir might bear his memory:
#   But thou, contracted to thine own bright eyes,
#   Feed'st thy light'st flame with self-substantial fuel,
#   Making a famine where abundance lies,
#   Thyself thy foe, to thy sweet self too cruel.
#   Thou that art now the world's fresh ornament
#   And only herald to the gaudy spring,
#   Within thine own bud buriest thy content
#   And, tender churl, makest waste in niggarding.
#   Pity the world, or else this glutton be,
#   To eat the world's due, by the grave and thee.
#
# Generated:
# FROM fairest creatures we desire increase, and so we ought not to have to look at any other creature than that which is beautiful, of which we choose beautiful.
#
#   Here is a comparison of each species, which makes it quite clear that in order to preserve and strengthen them we must keep them together. But to protect their species from external dangers is to maintain their peace and vigor; and to keep each creature healthy and independent is not merely to make it more resilient to external injuries, but also to help maintain its own life. For in every case, whether it be physical, moral, psychological, spiritual, or spiritual—if one of them is healthy or healthy—there should be one or more qualities in each one, as the species determines it. There should not be a uniform ratio of virtues to vices. The two traits of one species must be harmonized perfectly before it can have any rights, so long as it does not injure other species. And therefore there must surely
#
# BLEU Score: 0.0363
#
# Sonnet 2:
# Original:
# When forty winters shall beseige thy brow,
#   And dig deep trenches in thy beauty's field,
#   Thy youth's proud livery, so gazed on now,
#   Will be a tatter'd weed, of small worth held:
#   Then being ask'd where all thy beauty lies,
#   Where all the treasure of thy lusty days,
#   To say, within thine own deep-sunken eyes,
#   Were an all-eating shame and thriftless praise.
#   How much more praise deserved thy beauty's use,
#   If thou couldst answer 'This fair child of mine
#   Shall sum my count and make my old excuse,'
#   Proving his beauty by succession thine!
#   This were to be new made when thou art old,
#   And see thy blood warm when thou feel'st it cold.
#
# Generated:
# When forty winters shall beseige thy brow, thou shalt see that my brow is so much darkened that thy heart shall no longer be clean and your spirit has lost its grip upon it: for I would not have been able to see this unless thou were thyself aware of this vision.
#
#   You saw me there, and I saw thee there. I was lying supine on thy right breast, a garment of shining iron. Your face was white from the inside; and thou hast given birth to two daughters. My face bore scars of blackened bone; I had gone blind by exposure; thou had deceived me. Behold! I see thee, my friend! This is my master, thy servant, who I am to take by my hand. You must take me by your left hand, as far as I can see; for in my power, I dare not take you. This hand is very sharp, for it bends toward you easily. But you must keep the other hand and
#
# BLEU Score: 0.0476
#
# Sonnet 3:
# Original:
# Look in thy glass, and tell the face thou viewest
#   Now is the time that face should form another;
#   Whose fresh repair if now thou not renewest,
#   Thou dost beguile the world, unbless some mother.
#   For where is she so fair whose unear'd womb
#   Disdains the tillage of thy husbandry?
#   Or who is he so fond will be the tomb
#   Of his self-love, to stop posterity?
#   Thou art thy mother's glass, and she in thee
#   Calls back the lovely April of her prime:
#   So thou through windows of thine age shall see
#   Despite of wrinkles this thy golden time.
#   But if thou live, remember'd not to be,
#   Die single, and thine image dies with thee.
#
# Generated:
# Look in thy glass, and tell the face thou viewest, that ye may bear witness that thou art worthy of a place in heaven above all men, of which I have spoken; that, being all wise, ye might be worthy to this place, which is among the most holy places in the world, for to be a man of understanding and understanding, is to receive eternal life.
#
#   Now ye should walk in every direction that you would have taken, in all respects, with all your might, as I go along: for whatsoever way I may go in, it is no purpose to lead them into error. And when I return to my work, I will have them give heed to me, saying, We believe nothing of this doctrine, save in so far as it has been accepted by our professors; but we are in a state of contrition for it, since it does not appear from our own hearts to have any kind of infallible authority. But when we have believed it
#
# BLEU Score: 0.0629
#
# Sonnet 4:
# Original:
# Unthrifty loveliness, why dost thou spend
#   Upon thyself thy beauty's legacy?
#   Nature's bequest gives nothing but doth lend,
#   And being frank she lends to those are free.
#   Then, beauteous niggard, why dost thou abuse
#   The bounteous largess given thee to give?
#   Profitless usurer, why dost thou use
#   So great a sum of sums, yet canst not live?
#   For having traffic with thyself alone,
#   Thou of thyself thy sweet self dost deceive.
#   Then how, when nature calls thee to be gone,
#   What acceptable audit canst thou leave?
#   Thy unused beauty must be tomb'd with thee,
#   Which, used, lives th' executor to be.
#
# Generated:
# Unthrifty loveliness, why dost thou spend so much time talking to me? Is not that to make me feel better?
#
#   Now that I understand what you mean, I must say that a true scholar does not sit in his own home and spend his days playing music; on the contrary he spends his life wandering about the countryside, travelling to and fro, hunting, fishing, gathering berries, drinking a few beers, and so on until he comes to an end. To him, there are no other distractions at all.
#   . . .
#   "I don't want to hear you talk about what I do," I said, "I want you to listen. You'll tell me about it when you get there."
#    (It wasn't my idea to ask her if I'd like to know more about my own hobby as I waited. I felt a chill creep down my spine, a kind of guilt that would make anyone in the room cry out, but I
#
# BLEU Score: 0.0354
#
# Sonnet 5:
# Original:
# Those hours, that with gentle work did frame
#   The lovely gaze where every eye doth dwell,
#   Will play the tyrants to the very same
#   And that unfair which fairly doth excel:
#   For never-resting time leads summer on
#   To hideous winter and confounds him there;
#   Sap cheque'd with frost and lusty leaves quite gone,
#   Beauty o'ersnow'd and bareness every where:
#   Then, were not summer's distillation left,
#   A liquid prisoner pent in walls of glass,
#   Beauty's effect with beauty were bereft,
#   Nor it nor no remembrance what it was:
#   But flowers distill'd though they with winter meet,
#   Leese but their show; their substance still lives sweet.
#
# Generated:
# Those hours, that with gentle work did frame his imagination for a lot of different things.
#
#   In his latest memoir, "The Art of the Deal," published in 2010, Harper sought to paint a picture of "the great highs and lows of our lives." The book followed up with an essay about how Canadians look at themselves in relation to "their own choices, their choices," and that their choice of what was most important — and especially important to them — has affected the way they view themselves and the world around them. In particular, he argues that we tend to think of ourselves in terms of some kind of moral obligation, a responsibility to a friend, to the things we really want in life, or to our parents. This sense of obligation is central to his book, and for good reason. We are compelled to choose to behave in a certain way in public (or on a particular night) based on our own beliefs about what's right and wrong — for example, whether we are
#
# BLEU Score: 0.0502
#
# Sonnet 6:
# Original:
# Then let not winter's ragged hand deface
#   In thee thy summer, ere thou be distill'd:
#   Make sweet some vial; treasure thou some place
#   With beauty's treasure, ere it be self-kill'd.
#   That use is not forbidden usury,
#   Which happies those that pay the willing loan;
#   That's for thyself to breed another thee,
#   Or ten times happier, be it ten for one;
#   Ten times thyself were happier than thou art,
#   If ten of thine ten times refigured thee:
#   Then what could death do, if thou shouldst depart,
#   Leaving thee living in posterity?
#   Be not self-will'd, for thou art much too fair
#   To be death's conquest and make worms thine heir.
#
# Generated:
# Then let not winter's ragged hand deface the door of his father's home and he would be unable to get out, so he set out with his mother, the youngest brother of the family, to search for his uncle.
#
#   For the next several weeks he searched a little more intensely than usual for those who might have gone missing. The most common of them was a black man known simply as "Diddy," and this man took the bait when he went looking for him. After nearly a year and a half of searching, Diddy had become convinced that what he had seen of Danny Brown was all he could get. It was almost a miracle that the boy remembered where he'd gone — and where there had been nowhere to go and no sign of trouble in his hometown. Dixie Carter, he reasoned, probably had just gotten lost in the woods, leaving behind some of her old books and an older copy of Jane Austen's The Colour of Summer and The Curse of a
#
# BLEU Score: 0.0416
#
# Sonnet 7:
# Original:
# Lo! in the orient when the gracious light
#   Lifts up his burning head, each under eye
#   Doth homage to his new-appearing sight,
#   Serving with looks his sacred majesty;
#   And having climb'd the steep-up heavenly hill,
#   Resembling strong youth in his middle age,
#   yet mortal looks adore his beauty still,
#   Attending on his golden pilgrimage;
#   But when from highmost pitch, with weary car,
#   Like feeble age, he reeleth from the day,
#   The eyes, 'fore duteous, now converted are
#   From his low tract and look another way:
#   So thou, thyself out-going in thy noon,
#   Unlook'd on diest, unless thou get a son.
#
# Generated:
# Lo! in the orient when the gracious light arrives.
#
#   The second time around, I heard nothing. The next time I tried it, however, the light was still dim and the image faded. It was clearly visible on my map, but it was nowhere near as bright as before. My intuition was right. I didn't want to be seen as a ghost by anyone. As a matter of fact, it appeared to me so much more terrifying than I'd anticipated. All I could do was to blink. Not only did I notice my surroundings, my brain reacted so quickly and rapidly that it didn
#    (eventually) have a panic attack and immediately make a decision. (This reaction was fairly quick, and it wasn't an attack. But in retrospect, that was a completely out-of-bounds mistake. This was my mistake.)
#    of course, this was in a hurry (as I wasn
#   \begin{align*} &{\color{EF5C9
#
# BLEU Score: 0.0535
#
# Sonnet 8:
# Original:
# Music to hear, why hear'st thou music sadly?
#   Sweets with sweets war not, joy delights in joy.
#   Why lovest thou that which thou receivest not gladly,
#   Or else receivest with pleasure thine annoy?
#   If the true concord of well-tuned sounds,
#   By unions married, do offend thine ear,
#   They do but sweetly chide thee, who confounds
#   In singleness the parts that thou shouldst bear.
#   Mark how one string, sweet husband to another,
#   Strikes each in each by mutual ordering,
#   Resembling sire and child and happy mother
#   Who all in one, one pleasing note do sing:
#   Whose speechless song, being many, seeming one,
#   Sings this to thee: 'thou single wilt prove none.'
#
# Generated:
# Music to hear, why hear'st thou music sadly? Why listen to music that can't be heard, and what exactly does it mean for you to learn to listen?
#
#   It's quite common for music to have a certain sort of preoccupation with specific sounds — like a guitar solo or a track written for an opera — that isn't particularly suitable for children, a group of people, or even a loved one.
#   . . .
#    (I'm using "this" loosely here. I don't mean that literally — it's possible to say "I do not understand how a melody would feel if I wasn't reading it aloud" — but it isn
#    that difficult to understand or understand a good melody when you don
#   -speak in a way that sounds familiar
#
#
#
#   An easy way to explain that I understand
#   :
#    "What do you mean by 'what?'"?
#   (I don - but I've never tried to make any sense of 'something')
#
# BLEU Score: 0.0543
#
# Sonnet 9:
# Original:
# Is it for fear to wet a widow's eye
#   That thou consumest thyself in single life?
#   Ah! if thou issueless shalt hap to die.
#   The world will wail thee, like a makeless wife;
#   The world will be thy widow and still weep
#   That thou no form of thee hast left behind,
#   When every private widow well may keep
#   By children's eyes her husband's shape in mind.
#   Look, what an unthrift in the world doth spend
#   Shifts but his place, for still the world enjoys it;
#   But beauty's waste hath in the world an end,
#   And kept unused, the user so destroys it.
#   No love toward others in that bosom sits
#   That on himself such murderous shame commits.
#
# Generated:
# Is it for fear to wet a widow's eye that she will die after drinking wine?
#
#   A. Oh, I'd imagine so.
#    (Sensing that I am missing some of the interesting bits of information here, she proceeds to suggest that any kind of wine-loving lover should give wine a try if they are sober, but this does not seem to do much. I know it's tempting, seeing as I live in a pretty wealthy state, for example.) I suppose I can do a little research about the subject – I've had a lot of fun with this – but for now, let's focus on my findings. In fact, what I found surprising was that, unlike most people I met, most of them did not know anyone who drank wine, at least not at the time – they just never considered it important or appreciated its beauty or purity. So I decided to just take my wine to a friend who seemed to enjoy it. We're in the middle of a
#
# BLEU Score: 0.0594
#
# Sonnet 10:
# Original:
# For shame! deny that thou bear'st love to any,
#   Who for thyself art so unprovident.
#   Grant, if thou wilt, thou art beloved of many,
#   But that thou none lovest is most evident;
#   For thou art so possess'd with murderous hate
#   That 'gainst thyself thou stick'st not to conspire.
#   Seeking that beauteous roof to ruinate
#   Which to repair should be thy chief desire.
#   O, change thy thought, that I may change my mind!
#   Shall hate be fairer lodged than gentle love?
#   Be, as thy presence is, gracious and kind,
#   Or to thyself at least kind-hearted prove:
#   Make thee another self, for love of me,
#   That beauty still may live in thine or thee.
#
# Generated:
# For shame! deny that thou bear'st love to any, so that he may not become ashamed of thee, by denying that there should be any whom thou hast loved in thy desire for him, or that thine love hath not so much pleased him as thou didst deserve it: for I have heard that all men are called to love their neighbor, as if they would bear children together with him. For what shall I say of him who loves his neighbor as thyself, and yet does not love him at all?
#
#   I have been commanded by God to judge and love my enemies. I am commanded to do as much as I can to help them.
#    - Revelation 19:1-28
#    (NIV)
#   . . .
#    I fear that my beloved son will soon depart from my presence; for as soon as the Lord came to my house and said to me, "I know that you will not be able to bear my son," I immediately set my hand
#
# BLEU Score: 0.0686
#
# Sonnet 11:
# Original:
# As fast as thou shalt wane, so fast thou growest
#   In one of thine, from that which thou departest;
#   And that fresh blood which youngly thou bestowest
#   Thou mayst call thine when thou from youth convertest.
#   Herein lives wisdom, beauty and increase:
#   Without this, folly, age and cold decay:
#   If all were minded so, the times should cease
#   And threescore year would make the world away.
#   Let those whom Nature hath not made for store,
#   Harsh featureless and rude, barrenly perish:
#   Look, whom she best endow'd she gave the more;
#   Which bounteous gift thou shouldst in bounty cherish:
#   She carved thee for her seal, and meant thereby
#   Thou shouldst print more, not let that copy die.
#
# Generated:
# As fast as thou shalt wane, so fast thou growest a man: and it shall come to pass that he that with thine hand shall be clothed with thining hand, and a portion thereof shall go forth to thize and to thy enemies.
#
#   Chapter 10.—1. Thou shalt not be put to death.
#
#
#   This verse was first printed in 1529 in a commentary by Samuel Pepys (who was a prominent preacher of Anglicanism) and contains a clear condemnation of the devil. As is well known, the text of this verse (called "Rite of St. John") deals exclusively with the doctrine of hell; it is a fairly orthodox version of what is taught in the Gospels. What follows are some of these verses. While they are of minor character and are not important to the general reader, they provide a good overview of Jesus' life and teachings. The earliest Gospel traditions in particular are consistent with what I've read. This text is an
#
# BLEU Score: 0.0664
#
# Sonnet 12:
# Original:
# When I do count the clock that tells the time,
#   And see the brave day sunk in hideous night;
#   When I behold the violet past prime,
#   And sable curls all silver'd o'er with white;
#   When lofty trees I see barren of leaves
#   Which erst from heat did canopy the herd,
#   And summer's green all girded up in sheaves
#   Borne on the bier with white and bristly beard,
#   Then of thy beauty do I question make,
#   That thou among the wastes of time must go,
#   Since sweets and beauties do themselves forsake
#   And die as fast as they see others grow;
#   And nothing 'gainst Time's scythe can make defence
#   Save breed, to brave him when he takes thee hence.
#
# Generated:
# When I do count the clock that tells the time, I still end up with a time which is a few seconds behind me – in my case, a little less than a minute before we're supposed to begin. As we have already talked about, it's not necessarily in the best interest of a computer to tell you exactly when something is going to happen, but I can't seem to find anything that suggests that it isn't going into effect.
#
#   So when you're ready to hand over your PC to your local PC authority, you'll need to get all of your key files off your system, such as BIOS and drivers, to make sure they're running optimally. If they fail to do so, the system will automatically go out of operation. However, this will not immediately lead to a crash, so keep an eye on your drive for any suspicious behaviour. In particular, make your hard drive a lot smaller than necessary in order to ensure that you don't accidentally push a piece
#
# BLEU Score: 0.0652
#
# Sonnet 13:
# Original:
# O, that you were yourself! but, love, you are
#   No longer yours than you yourself here live:
#   Against this coming end you should prepare,
#   And your sweet semblance to some other give.
#   So should that beauty which you hold in lease
#   Find no determination: then you were
#   Yourself again after yourself's decease,
#   When your sweet issue your sweet form should bear.
#   Who lets so fair a house fall to decay,
#   Which husbandry in honour might uphold
#   Against the stormy gusts of winter's day
#   And barren rage of death's eternal cold?
#   O, none but unthrifts! Dear my love, you know
#   You had a father: let your son say so.
#
# Generated:
# O, that you were yourself! but, love, you are a human, so when you saw your sister cry your heart leapt to life, and the pain was so great that it almost scared me.
#
#   I remember a day that I remember almost as much now, as I did two years ago, when I went into my room, with my daughter alone, to buy a gift for her. I didn't know what she was looking for, but when she asked if there was something in the box, I answered: "No, nothing." But as soon as she opened the door and saw me, she immediately started walking away. It was a horrible feeling. That day I had gone to a party, where the only thing I felt was disgust. All those who had supported my cause (and who hadn't been so lucky), had stopped following me or paying attention, or stopped making a decision that could lead to serious harm. In fact, all those people were furious that they hadn
#
# BLEU Score: 0.0581
#
# Sonnet 14:
# Original:
# Not from the stars do I my judgment pluck;
#   And yet methinks I have astronomy,
#   But not to tell of good or evil luck,
#   Of plagues, of dearths, or seasons' quality;
#   Nor can I fortune to brief minutes tell,
#   Pointing to each his thunder, rain and wind,
#   Or say with princes if it shall go well,
#   By oft predict that I in heaven find:
#   But from thine eyes my knowledge I derive,
#   And, constant stars, in them I read such art
#   As truth and beauty shall together thrive,
#   If from thyself to store thou wouldst convert;
#   Or else of thee this I prognosticate:
#   Thy end is truth's and beauty's doom and date.
#
# Generated:
# Not from the stars do I my judgment pluck; they say a man may not marry.
#
#   But what is it that makes a woman love a wife who is not in love with her husband? And what do they think she has in common with him? If she loves him dearly, what good is in him except his love?
#    I will tell you. I love him very much. He loves me very dearly; he gives me a great deal. It is natural and natural that a husband should love his wife so much as to grant her a large share of her property, or a smaller share; that is, to provide a stable husband to his family and friends; but it seems to me, then, that such an arrangement should be regarded with great caution. Not only is love ungrateful, yet so am I. What am the consequences of this? Do they prove anything? I am not sure, but they give an idea of what I have thought or thought about him
#
# BLEU Score: 0.0654
#
# Sonnet 15:
# Original:
# When I consider every thing that grows
#   Holds in perfection but a little moment,
#   That this huge stage presenteth nought but shows
#   Whereon the stars in secret influence comment;
#   When I perceive that men as plants increase,
#   Cheered and cheque'd even by the self-same sky,
#   Vaunt in their youthful sap, at height decrease,
#   And wear their brave state out of memory;
#   Then the conceit of this inconstant stay
#   Sets you most rich in youth before my sight,
#   Where wasteful Time debateth with Decay,
#   To change your day of youth to sullied night;
#   And all in war with Time for love of you,
#   As he takes from you, I engraft you new.
#
# Generated:
# When I consider every thing that grows inside me, I've got a theory for what I do and how I am doing it.
#
#   I was raised in a household where everything was a secret and that all secrets were kept as private as you could possibly imagine. I came to realize that if I ever learned my secret, it would be for nothing more than a mere curiosity and for fear that I would find out what it was I was hiding. And for me it all sounded so strange and unexpected. It was odd, a completely unfamiliar feeling, but that made it feel so right to me. Suddenly I thought that perhaps I'd seen something I hadn't seen before and was quite certain that my friend and I had discovered it early on – something that we'd both seen from a distance and which had puzzled me as well. Then, suddenly, something happened. Something that had almost always come to be believed before – that something hadn
#   . Nothing. Instead it had been found by the detective on
#
# BLEU Score: 0.0442
#
# Sonnet 16:
# Original:
# But wherefore do not you a mightier way
#   Make war upon this bloody tyrant, Time?
#   And fortify yourself in your decay
#   With means more blessed than my barren rhyme?
#   Now stand you on the top of happy hours,
#   And many maiden gardens yet unset
#   With virtuous wish would bear your living flowers,
#   Much liker than your painted counterfeit:
#   So should the lines of life that life repair,
#   Which this, Time's pencil, or my pupil pen,
#   Neither in inward worth nor outward fair,
#   Can make you live yourself in eyes of men.
#   To give away yourself keeps yourself still,
#   And you must live, drawn by your own sweet skill.
#
# Generated:
# But wherefore do not you a mightier way of saying than that they were created by your own creation? For that matter, if thou art a creature of God and thyself was created, where then shouldst thou judge? And how dost I judge thee? Because I believe this man is my Christ; and that I am his Son, and am now his priest; because of his righteousness I have persecuted the wicked among me, he that believes in me; for I know not how I might be judged. Wherefore have I judged thee that thou hast been an abomination unto me? Where, then, hath she taken thy revenge? But she herself hath chosen for this purpose a woman, in order that she may not be deceived. Nay, she has chosen that woman as her agent, for all that is required in this dispensation. And she chose to follow me in her own heart: for behold, I saw a serpent that fell from the sky and came down to meet me
#
# BLEU Score: 0.0559
#
# Sonnet 17:
# Original:
# Who will believe my verse in time to come,
#   If it were fill'd with your most high deserts?
#   Though yet, heaven knows, it is but as a tomb
#   Which hides your life and shows not half your parts.
#   If I could write the beauty of your eyes
#   And in fresh numbers number all your graces,
#   The age to come would say 'This poet lies:
#   Such heavenly touches ne'er touch'd earthly faces.'
#   So should my papers yellow'd with their age
#   Be scorn'd like old men of less truth than tongue,
#   And your true rights be term'd a poet's rage
#   And stretched metre of an antique song:
#   But were some child of yours alive that time,
#   You should live twice; in it and in my rhyme.
#
# Generated:
# Who will believe my verse in time to come, shall believe in my righteousness, and shall proclaim my will and my plan in all His works? Blessed is he who has been able to enter into His own soul, to act in His soul and make a will with His will, having received it from Him, but lacking it in the divine and divinely inspired word, who will then proceed with his actions to follow their directions and obtain their object?
#
#   It seems to me absurd that, given that the Lord Almighty willed, He should have bestowed upon Hezekiah a portion of the kingdom which had been obtained by means of inheritance from His Son, when He had already set down His commandments. But even if this was so, it would not be a very bad thing to do so; for the covenant of faith (Isaiah 58:1) was not a substantial part of His kingdom; it was a privilege derived by Him from those who loved Him; and because that privilege was granted
#
# BLEU Score: 0.0643
#
# Sonnet 18:
# Original:
# Shall I compare thee to a summer's day?
#   Thou art more lovely and more temperate:
#   Rough winds do shake the darling buds of May,
#   And summer's lease hath all too short a date:
#   Sometime too hot the eye of heaven shines,
#   And often is his gold complexion dimm'd;
#   And every fair from fair sometime declines,
#   By chance or nature's changing course untrimm'd;
#   But thy eternal summer shall not fade
#   Nor lose possession of that fair thou owest;
#   Nor shall Death brag thou wander'st in his shade,
#   When in eternal lines to time thou growest:
#   So long as men can breathe or eyes can see,
#   So long lives this and this gives life to thee.
#
# Generated:
# Shall I compare thee to a summer's day? It is not such a fair thing if I were to lay down my life and go to sleep as before. I see that I shall have a dream, and it is for that purpose of being a present to my mother, that this morning I should be able to do something which I will, as far as I can see, have not yet mastered.
#
#   The dream occurs before waking up and immediately after waking, which is when the mind enters a state of euphoria. The subject is lucid, conscious and present. After waking the subject experiences a feeling of ecstasy and ecstasy-pushing at his own disposal. He is now free from the effects of what he was experiencing, but his mood is very similar to what had preceded it. It has become a regular feature of his mind, since he has not experienced a conscious or unconscious experience. Rather, it has been a part of him that has undergone great trauma. This trauma has resulted
#
# BLEU Score: 0.0547
#
# Sonnet 19:
# Original:
# Devouring Time, blunt thou the lion's paws,
#   And make the earth devour her own sweet brood;
#   Pluck the keen teeth from the fierce tiger's jaws,
#   And burn the long-lived phoenix in her blood;
#   Make glad and sorry seasons as thou fleets,
#   And do whate'er thou wilt, swift-footed Time,
#   To the wide world and all her fading sweets;
#   But I forbid thee one most heinous crime:
#   O, carve not with thy hours my love's fair brow,
#   Nor draw no lines there with thine antique pen;
#   Him in thy course untainted do allow
#   For beauty's pattern to succeeding men.
#   Yet, do thy worst, old Time: despite thy wrong,
#   My love shall in my verse ever live young.
#
# Generated:
# Devouring Time, blunt thou the lion's paws, and let thee not fall into the sea, let her be free; let it be a free place, to give her to your hand; I give you to carry with me, a little of it and to make myself free, with my own, from this world, by what I call divine law.
#
#   This, then, must be my answer: That my mother loved me and gave me to her in a dream, which was not in reality my dream at all: for it was a delusion, that I had seen my son lying dead under a tree in the woods, surrounded by two strangers; and that she had known them and been as sure as day that they would not have done such a thing. She was still alive, she said, for she loved him so dearly, but that this was entirely untrue; that he was dead and in perfect health, as if they could see it through, before she could say so.
#
# BLEU Score: 0.0455
#
# Sonnet 20:
# Original:
# A woman's face with Nature's own hand painted
#   Hast thou, the master-mistress of my passion;
#   A woman's gentle heart, but not acquainted
#   With shifting change, as is false women's fashion;
#   An eye more bright than theirs, less false in rolling,
#   Gilding the object whereupon it gazeth;
#   A man in hue, all 'hues' in his controlling,
#   Much steals men's eyes and women's souls amazeth.
#   And for a woman wert thou first created;
#   Till Nature, as she wrought thee, fell a-doting,
#   And by addition me of thee defeated,
#   By adding one thing to my purpose nothing.
#   But since she prick'd thee out for women's pleasure,
#   Mine be thy love and thy love's use their treasure.
#
# Generated:
# A woman's face with Nature's own hand painted on a piece of paper by someone else.
#
#   The woman was apparently trying to get some sort of financial contribution from someone a few days after they'd had a miscarriage. But she didn't seem to want to admit it – there weren't enough of them, and they weren
#    (at least, until she saw them in the hospital) having miscarriages. What could that mean?
#   :She wanted to donate to charity in hopes that maybe this might be one of her favours. As it turned out, she couldn't (and still couldn (when she went to try and donate a bottle of water) – although she's always been a pretty generous person. It hasn't been too difficult to make a really small donation on the internet (or even for a small fee!) to a cause that her friends seem genuinely sympathetic towards. (I wonder if it would cost her much, if she hadn't already decided to stop asking for donations
#
# BLEU Score: 0.0554
#
# Average BLEU: 0.0542

# %%
import warnings
warnings.filterwarnings("ignore")

from transformers import AutoTokenizer, AutoModelForCausalLM
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
# Out:
# === Prompts (First Lines of Each Sonnet) ===
# Prompt 1: FROM fairest creatures we desire increase,
# Prompt 2: When forty winters shall beseige thy brow,
# Prompt 3: Look in thy glass, and tell the face thou viewest
# Prompt 4: Unthrifty loveliness, why dost thou spend
# Prompt 5: Those hours, that with gentle work did frame
# Prompt 6: Then let not winter's ragged hand deface
# Prompt 7: Lo! in the orient when the gracious light
# Prompt 8: Music to hear, why hear'st thou music sadly?
# Prompt 9: Is it for fear to wet a widow's eye
# Prompt 10: For shame! deny that thou bear'st love to any,
# Prompt 11: As fast as thou shalt wane, so fast thou growest
# Prompt 12: When I do count the clock that tells the time,
# Prompt 13: O, that you were yourself! but, love, you are
# Prompt 14: Not from the stars do I my judgment pluck;
# Prompt 15: When I consider every thing that grows
# Prompt 16: But wherefore do not you a mightier way
# Prompt 17: Who will believe my verse in time to come,
# Prompt 18: Shall I compare thee to a summer's day?
# Prompt 19: Devouring Time, blunt thou the lion's paws,
# Prompt 20: A woman's face with Nature's own hand painted

# %%
with open("sonnets.txt", "r") as file:
    sonnets_text = file.read()

sonnets = [sonnet.strip() for sonnet in sonnets_text.split('\n\n') if sonnet.strip()]
sonnets = sonnets[:20]

prompts = [sonnet.split('\n')[0] for sonnet in sonnets]
original_sonnets = sonnets

print("\n=== Prompts (First Lines of Each Sonnet) ===")
for i, prompt in enumerate(prompts, 1):
    print(f"Prompt {i}: {prompt}")
print("\n")

# %%
model_name = "ayazfau/GPT2-124M-poetry-RL"
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name).eval()
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# %%
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.pad_token_id = tokenizer.eos_token_id

# %%
def generate_verse(prompt, max_length=200, temperature=0.8, top_k=40, top_p=0.95):
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        padding=True,
        return_attention_mask=True
    )
    outputs = model.generate(
        input_ids=inputs['input_ids'],
        attention_mask=inputs['attention_mask'],
        max_length=max_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        num_return_sequences=1,
        pad_token_id=tokenizer.pad_token_id,
        no_repeat_ngram_size=2,
        do_sample=True
    )
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
generated_sonnets = []
bleu_scores = []
smoothie = SmoothingFunction().method4

for prompt, original in zip(prompts, original_sonnets):
    generated_verse = generate_verse(prompt)
    generated_sonnets.append(generated_verse)

    reference = [original.split()]
    candidate = generated_verse.split()
    score = sentence_bleu(reference, candidate, smoothing_function=smoothie)
    bleu_scores.append(score)
# Out:
# === Final Comparison: Original vs. Generated Sonnets ===
#
# Sonnet 1:
# Original:
# FROM fairest creatures we desire increase,
#   That thereby beauty's rose might never die,
#   But as the riper should by time decease,
#   His tender heir might bear his memory:
#   But thou, contracted to thine own bright eyes,
#   Feed'st thy light'st flame with self-substantial fuel,
#   Making a famine where abundance lies,
#   Thyself thy foe, to thy sweet self too cruel.
#   Thou that art now the world's fresh ornament
#   And only herald to the gaudy spring,
#   Within thine own bud buriest thy content
#   And, tender churl, makest waste in niggarding.
#   Pity the world, or else this glutton be,
#   To eat the world's due, by the grave and thee.
#
# Generated:
# FROM fairest creatures we desire increase, and we will not be able to do so without the help of the people.
#
#   The people will be the first to see that we are not only a nation, but a people, that is, a country. We will have a government that will protect us from the dangers of our own government, from those who seek to destroy us, to those that seek our destruction. And we shall have the power to make our government a better one, one that does not seek the destruction of others. The people shall be our first and only hope.
#
# BLEU Score: 0.0576
#
# Sonnet 2:
# Original:
# When forty winters shall beseige thy brow,
#   And dig deep trenches in thy beauty's field,
#   Thy youth's proud livery, so gazed on now,
#   Will be a tatter'd weed, of small worth held:
#   Then being ask'd where all thy beauty lies,
#   Where all the treasure of thy lusty days,
#   To say, within thine own deep-sunken eyes,
#   Were an all-eating shame and thriftless praise.
#   How much more praise deserved thy beauty's use,
#   If thou couldst answer 'This fair child of mine
#   Shall sum my count and make my old excuse,'
#   Proving his beauty by succession thine!
#   This were to be new made when thou art old,
#   And see thy blood warm when thou feel'st it cold.
#
# Generated:
# When forty winters shall beseige thy brow, and thy hair shall be white, thou shalt not be ashamed of thyself.
#
#   And thou shall not lie, nor lie in thy bed,
#   . And thou, O Lord, shalt be a man of God.
#
#
#   CHAPTER XXII. The Lord's Prayer. (1)
#   , "O Lord! O God, I am the Lord;
#    (2) Thou shalt love thy neighbour as thy own; (3) thou art the God of Israel;
#
#   . . .
#
#
#
#
#   And the LORD said unto him, Behold, the day of the resurrection, when the angels shall come to thee,
#
#    (4) and the angel of David shall say unto thee:
#    "Behold! I will make thee a king, a God; and I shall make thy people a people of my own, (5) a nation of mine own. Be thou therefore a son of man, that thou mayest be
#
# BLEU Score: 0.0646
#
# Sonnet 3:
# Original:
# Look in thy glass, and tell the face thou viewest
#   Now is the time that face should form another;
#   Whose fresh repair if now thou not renewest,
#   Thou dost beguile the world, unbless some mother.
#   For where is she so fair whose unear'd womb
#   Disdains the tillage of thy husbandry?
#   Or who is he so fond will be the tomb
#   Of his self-love, to stop posterity?
#   Thou art thy mother's glass, and she in thee
#   Calls back the lovely April of her prime:
#   So thou through windows of thine age shall see
#   Despite of wrinkles this thy golden time.
#   But if thou live, remember'd not to be,
#   Die single, and thine image dies with thee.
#
# Generated:
# Look in thy glass, and tell the face thou viewest, that thou mayest see the light of the Lord.
#
#   (2) And when thou sawest the glory of God, thou shalt be a witness of it. (3)
#   . . .
#    (4) For the LORD is the God of all things, the Father of heaven and earth, who is in heaven, in the earth and in all that is between. And the Son of man is God in his own image, as the sun and the moon. The Father is also the image of his Son, which is his glory. He is not the only one, but the whole is one. Therefore, if thou wilt see that the Holy Spirit is with thee, then thou must be witness to it, because it is true. For it was written, "Thou shalt not be afraid of men."
#   , . (5) But if ye see, behold, I am the Spirit of life,
#
# BLEU Score: 0.0771
#
# Sonnet 4:
# Original:
# Unthrifty loveliness, why dost thou spend
#   Upon thyself thy beauty's legacy?
#   Nature's bequest gives nothing but doth lend,
#   And being frank she lends to those are free.
#   Then, beauteous niggard, why dost thou abuse
#   The bounteous largess given thee to give?
#   Profitless usurer, why dost thou use
#   So great a sum of sums, yet canst not live?
#   For having traffic with thyself alone,
#   Thou of thyself thy sweet self dost deceive.
#   Then how, when nature calls thee to be gone,
#   What acceptable audit canst thou leave?
#   Thy unused beauty must be tomb'd with thee,
#   Which, used, lives th' executor to be.
#
# Generated:
# Unthrifty loveliness, why dost thou spend thy time in the world of the dead?
#
#   The Lord is the Lord, and the Father is in heaven.
#   . . .
#    (2) The Lord's Prayer. The Holy Spirit is at work in all things. He is working in us, in our hearts, our minds, the hearts of our children, of all the nations. And he is doing it in a way that is not only pleasing to us but also pleasing unto God. (3) He has made us to be His servants. We are His children. Our Lord has given us the power to do good. But we are not His slaves. God has created us for His own good, for the good of His people. Therefore, we must be obedient to Him. If we do not obey Him, He will not forgive us. For He does not know what we ought to obey. So we should not be afraid of Him; for He
#
# BLEU Score: 0.0424
#
# Sonnet 5:
# Original:
# Those hours, that with gentle work did frame
#   The lovely gaze where every eye doth dwell,
#   Will play the tyrants to the very same
#   And that unfair which fairly doth excel:
#   For never-resting time leads summer on
#   To hideous winter and confounds him there;
#   Sap cheque'd with frost and lusty leaves quite gone,
#   Beauty o'ersnow'd and bareness every where:
#   Then, were not summer's distillation left,
#   A liquid prisoner pent in walls of glass,
#   Beauty's effect with beauty were bereft,
#   Nor it nor no remembrance what it was:
#   But flowers distill'd though they with winter meet,
#   Leese but their show; their substance still lives sweet.
#
# Generated:
# Those hours, that with gentle work did frame the idea of a "new" world.
#
#   "I think it's a very important thing to have a sense of what's going on in the world," he said. "I don't think we're going to be able to do that in a vacuum. We're not going be doing that. It's not something that we can do in our own time."
#   . . .
#    (The New York Times)
#   , "The new world is not a new one," said the former president. He said he was "very happy" with the way the United States has been doing things. But he also said that the "world is a different world" than the one he had envisioned. The United Nations has not been able, he added, to "make the same decisions as the rest of the industrialized world." He added that he would like to see the U.N. do more to help the developing world, but he did
#
# BLEU Score: 0.0523
#
# Sonnet 6:
# Original:
# Then let not winter's ragged hand deface
#   In thee thy summer, ere thou be distill'd:
#   Make sweet some vial; treasure thou some place
#   With beauty's treasure, ere it be self-kill'd.
#   That use is not forbidden usury,
#   Which happies those that pay the willing loan;
#   That's for thyself to breed another thee,
#   Or ten times happier, be it ten for one;
#   Ten times thyself were happier than thou art,
#   If ten of thine ten times refigured thee:
#   Then what could death do, if thou shouldst depart,
#   Leaving thee living in posterity?
#   Be not self-will'd, for thou art much too fair
#   To be death's conquest and make worms thine heir.
#
# Generated:
# Then let not winter's ragged hand deface the walls of the city.
#
#   The city was a city of thieves, and the thieves were the ones who stole the treasures of their enemies. The thieves had no need to be afraid of them, for they were not afraid to steal. They were afraid that they would be caught, but they did not fear that the thief would not be able to escape. And so, the robbers were able, because they had the power to break the wall of a town. But the town was not safe, so the robber was able only to flee. So, when the king of England came to the land of his enemies, he said to him, "I will not let you escape, my lord, nor will I let the people of this land escape." And the man said, 'I have no fear of you, Lord, I will let them escape.' And he went on to say, "'I am afraid, lord. I have not
#
# BLEU Score: 0.0418
#
# Sonnet 7:
# Original:
# Lo! in the orient when the gracious light
#   Lifts up his burning head, each under eye
#   Doth homage to his new-appearing sight,
#   Serving with looks his sacred majesty;
#   And having climb'd the steep-up heavenly hill,
#   Resembling strong youth in his middle age,
#   yet mortal looks adore his beauty still,
#   Attending on his golden pilgrimage;
#   But when from highmost pitch, with weary car,
#   Like feeble age, he reeleth from the day,
#   The eyes, 'fore duteous, now converted are
#   From his low tract and look another way:
#   So thou, thyself out-going in thy noon,
#   Unlook'd on diest, unless thou get a son.
#
# Generated:
# Lo! in the orient when the gracious light of the sun shines upon you.
#
#   The Lord is with you, O Lord, and you are with him.
#
# BLEU Score: 0.0175
#
# Sonnet 8:
# Original:
# Music to hear, why hear'st thou music sadly?
#   Sweets with sweets war not, joy delights in joy.
#   Why lovest thou that which thou receivest not gladly,
#   Or else receivest with pleasure thine annoy?
#   If the true concord of well-tuned sounds,
#   By unions married, do offend thine ear,
#   They do but sweetly chide thee, who confounds
#   In singleness the parts that thou shouldst bear.
#   Mark how one string, sweet husband to another,
#   Strikes each in each by mutual ordering,
#   Resembling sire and child and happy mother
#   Who all in one, one pleasing note do sing:
#   Whose speechless song, being many, seeming one,
#   Sings this to thee: 'thou single wilt prove none.'
#
# Generated:
# Music to hear, why hear'st thou music sadly?
#
#   I'm not sure what to say.
#   . . .
#    (I'll be back.)
#   ,
#   :
#   -
#   (I've got a lot of things to talk about.)-
#
#
#   The first thing I want to do is to tell you that I'm a very good listener. I've listened to a ton of music, and I know that it's not just a matter of listening to the same songs over and over again. It's a whole lot more about listening and listening.
#
#   .
#
# BLEU Score: 0.0700
#
# Sonnet 9:
# Original:
# Is it for fear to wet a widow's eye
#   That thou consumest thyself in single life?
#   Ah! if thou issueless shalt hap to die.
#   The world will wail thee, like a makeless wife;
#   The world will be thy widow and still weep
#   That thou no form of thee hast left behind,
#   When every private widow well may keep
#   By children's eyes her husband's shape in mind.
#   Look, what an unthrift in the world doth spend
#   Shifts but his place, for still the world enjoys it;
#   But beauty's waste hath in the world an end,
#   And kept unused, the user so destroys it.
#   No love toward others in that bosom sits
#   That on himself such murderous shame commits.
#
# Generated:
# Is it for fear to wet a widow's eye?
#
#   The answer is yes.
#   . . .
#    (The following is a transcript of the interview with the author.)
#   , . ."
#   "I'm not afraid of anything. I'm afraid that I'll be killed. And I don't want to be a part of it. But I want it to happen. It's not a matter of fear. The only thing I can do is to try to make it happen."
#   This is the same question that was asked by the writer of The New York Times Magazine in the early 1960s. "I don' t want anything to do with it," he said. He was referring to the fact that the United States had been invaded by a foreign power, and that he was not willing to accept that. In fact, he had no idea what he would do. His only hope was to get the war to end. So he went to Washington, D.C., and
#
# BLEU Score: 0.0557
#
# Sonnet 10:
# Original:
# For shame! deny that thou bear'st love to any,
#   Who for thyself art so unprovident.
#   Grant, if thou wilt, thou art beloved of many,
#   But that thou none lovest is most evident;
#   For thou art so possess'd with murderous hate
#   That 'gainst thyself thou stick'st not to conspire.
#   Seeking that beauteous roof to ruinate
#   Which to repair should be thy chief desire.
#   O, change thy thought, that I may change my mind!
#   Shall hate be fairer lodged than gentle love?
#   Be, as thy presence is, gracious and kind,
#   Or to thyself at least kind-hearted prove:
#   Make thee another self, for love of me,
#   That beauty still may live in thine or thee.
#
# Generated:
# For shame! deny that thou bear'st love to any, that thy love is not to thyself, but to the world.
#
#   (2) For the love of God is to all men, and to God the Father, the Son, or the Holy Ghost. For God has made man, not only to love God, as the angels have made him, to be loved by him. But God also has given to man the gift of love, which is the power to make man love himself. And God loves all things, even the things that are in him; and he loves the good things of the flesh, for they are good to him and good for him: and the evil things are evil to them, because they do not belong to Him. (3) And the Lord Jesus Christ, who is God and Father of all, is love unto all. He is loved in all the ways of his Father and in the way of His Son. The love that God gives
#
# BLEU Score: 0.0645
#
# Sonnet 11:
# Original:
# As fast as thou shalt wane, so fast thou growest
#   In one of thine, from that which thou departest;
#   And that fresh blood which youngly thou bestowest
#   Thou mayst call thine when thou from youth convertest.
#   Herein lives wisdom, beauty and increase:
#   Without this, folly, age and cold decay:
#   If all were minded so, the times should cease
#   And threescore year would make the world away.
#   Let those whom Nature hath not made for store,
#   Harsh featureless and rude, barrenly perish:
#   Look, whom she best endow'd she gave the more;
#   Which bounteous gift thou shouldst in bounty cherish:
#   She carved thee for her seal, and meant thereby
#   Thou shouldst print more, not let that copy die.
#
# Generated:
# As fast as thou shalt wane, so fast thou growest, and so shalt thou be.
#
#   (2) And thou wilt be a man, a woman, or a child, if thou hast not a wife. (3)
#   . . .
#    (4) But if a husband is not married, he shall not be able to have children. And if he is married to a widow, she shall be unable to bear children, for she is a virgin. But a father is able, because he has a son. If a mother is unable, then she will not have a daughter. For if she has children she cannot bear them. Therefore, the husband shall have to be married. The wife shall also have the right to inherit the land. So the father shall inherit it. Then the son shall become a king. He shall rule over the whole earth. Now the sons shall live in the earth, but the daughters shall dwell in heaven. They shall go forth
#
# BLEU Score: 0.0596
#
# Sonnet 12:
# Original:
# When I do count the clock that tells the time,
#   And see the brave day sunk in hideous night;
#   When I behold the violet past prime,
#   And sable curls all silver'd o'er with white;
#   When lofty trees I see barren of leaves
#   Which erst from heat did canopy the herd,
#   And summer's green all girded up in sheaves
#   Borne on the bier with white and bristly beard,
#   Then of thy beauty do I question make,
#   That thou among the wastes of time must go,
#   Since sweets and beauties do themselves forsake
#   And die as fast as they see others grow;
#   And nothing 'gainst Time's scythe can make defence
#   Save breed, to brave him when he takes thee hence.
#
# Generated:
# When I do count the clock that tells the time, I'm counting the number of days that I've been in the hospital. I don't know how many days I have been there.
#
#   "I'm not sure how long I was there, but I think I had a good time. It was a very good day. The doctor said, 'You're going to have to go to the emergency room.' I said 'No, no, you're not going.' He said to me, "You have a lot of time to live."
#   . . .
#    (The doctor) said that you have the right to stay in your home. He was very nice. And he said he was going back to work. So I went to my room and I sat down and he told me to sit down. Then he went back and said I should go back. But I didn't. That's when I started to feel like I wasn't going anywhere. My heart stopped. When
#
# BLEU Score: 0.0718
#
# Sonnet 13:
# Original:
# O, that you were yourself! but, love, you are
#   No longer yours than you yourself here live:
#   Against this coming end you should prepare,
#   And your sweet semblance to some other give.
#   So should that beauty which you hold in lease
#   Find no determination: then you were
#   Yourself again after yourself's decease,
#   When your sweet issue your sweet form should bear.
#   Who lets so fair a house fall to decay,
#   Which husbandry in honour might uphold
#   Against the stormy gusts of winter's day
#   And barren rage of death's eternal cold?
#   O, none but unthrifts! Dear my love, you know
#   You had a father: let your son say so.
#
# Generated:
# O, that you were yourself! but, love, you are not my love. I am not your love! I have no love for you. You are my lover.
#
#   I am your lover, and I will not let you go. But, I love you, my darling. Love is the only thing that can make me happy. And, if you love me, then I can't help it. If you don't love yourself, it's because you're not mine. It's not because I'm not yours. That's why I want you to love myself. Because I know you will love your own. So, please, don' t forget to tell me what you want. Please, tell my mother. Tell her what I need. She'll love it, too.
#
# BLEU Score: 0.0824
#
# Sonnet 14:
# Original:
# Not from the stars do I my judgment pluck;
#   And yet methinks I have astronomy,
#   But not to tell of good or evil luck,
#   Of plagues, of dearths, or seasons' quality;
#   Nor can I fortune to brief minutes tell,
#   Pointing to each his thunder, rain and wind,
#   Or say with princes if it shall go well,
#   By oft predict that I in heaven find:
#   But from thine eyes my knowledge I derive,
#   And, constant stars, in them I read such art
#   As truth and beauty shall together thrive,
#   If from thyself to store thou wouldst convert;
#   Or else of thee this I prognosticate:
#   Thy end is truth's and beauty's doom and date.
#
# Generated:
# Not from the stars do I my judgment pluck; but from my own, I am a man of my word.
#
#   I am not a prophet, but a person. I have no power to judge, and I do not know what to do with my life. But I know that I can judge. And I will judge for myself.
#
# BLEU Score: 0.0727
#
# Sonnet 15:
# Original:
# When I consider every thing that grows
#   Holds in perfection but a little moment,
#   That this huge stage presenteth nought but shows
#   Whereon the stars in secret influence comment;
#   When I perceive that men as plants increase,
#   Cheered and cheque'd even by the self-same sky,
#   Vaunt in their youthful sap, at height decrease,
#   And wear their brave state out of memory;
#   Then the conceit of this inconstant stay
#   Sets you most rich in youth before my sight,
#   Where wasteful Time debateth with Decay,
#   To change your day of youth to sullied night;
#   And all in war with Time for love of you,
#   As he takes from you, I engraft you new.
#
# Generated:
# When I consider every thing that grows in the world, I think that it's a very important thing to be able to do that.
#
#   "I think it is a great thing for the country to have a strong leader who is willing to take on the challenges that come with it. I'm sure that he will be very successful in his role as leader of the party. He will have the ability to bring the people together and to make sure they are able and able-bodied enough to get on with their lives. That's what I believe in."
#   .@realDonaldTrump: "I'm going to work hard to build a better America. We're going back to the drawing board. #MakeAmericaGreatAgain"
#    (via @realDonaldTrump) pic.twitter.com/Y6YXjZW5XJ — The Daily Caller (@TheDC) November 8, 2017
#   , "Trump's plan to rebuild the American economy is not a plan for a new America," Trump
#
# BLEU Score: 0.0516
#
# Sonnet 16:
# Original:
# But wherefore do not you a mightier way
#   Make war upon this bloody tyrant, Time?
#   And fortify yourself in your decay
#   With means more blessed than my barren rhyme?
#   Now stand you on the top of happy hours,
#   And many maiden gardens yet unset
#   With virtuous wish would bear your living flowers,
#   Much liker than your painted counterfeit:
#   So should the lines of life that life repair,
#   Which this, Time's pencil, or my pupil pen,
#   Neither in inward worth nor outward fair,
#   Can make you live yourself in eyes of men.
#   To give away yourself keeps yourself still,
#   And you must live, drawn by your own sweet skill.
#
# Generated:
# But wherefore do not you a mightier way of saying, 'I am not a man of the world'?
#
#   "I have been a member of this body for a long time, and I have never been in a position to say that I am a woman of God. I do believe that God is a person of grace, that He is the only one who can bring about the perfect union of man and woman.
#   . . .
#   ,
#    (1) The Bible says that the Lord Jesus Christ is God, the Son of Man, who is in the flesh, but who has been created in his image, by the power of his Father. (2) He was created by God to be a Man of His own, to have dominion over the earth, for the purpose of bringing about His perfection. He has also been made Man by His Father, through the Holy Spirit, in order that he might be made a God of men. The Lord is not the Father
#
# BLEU Score: 0.0497
#
# Sonnet 17:
# Original:
# Who will believe my verse in time to come,
#   If it were fill'd with your most high deserts?
#   Though yet, heaven knows, it is but as a tomb
#   Which hides your life and shows not half your parts.
#   If I could write the beauty of your eyes
#   And in fresh numbers number all your graces,
#   The age to come would say 'This poet lies:
#   Such heavenly touches ne'er touch'd earthly faces.'
#   So should my papers yellow'd with their age
#   Be scorn'd like old men of less truth than tongue,
#   And your true rights be term'd a poet's rage
#   And stretched metre of an antique song:
#   But were some child of yours alive that time,
#   You should live twice; in it and in my rhyme.
#
# Generated:
# Who will believe my verse in time to come, and will not believe it in eternity?
#
#   (2) The Lord said to Moses, "I will give you a new covenant, which I will make with you, that you may be saved from the curse of the law, from your sins, your infirmities, the infidelity of your fathers, you who have not been baptized, who are not true believers, but who believe in the Lord Jesus Christ, whom I have given you."
#    (3) And Moses said unto him, Behold, I am the LORD, my God, with all the prophets, all that I know, even the saints, of whom you have heard, saying, 'I am your God.'
#   .
#   ,
#   "And I said, O Lord, what is this, when I say, Thou art the God of Israel, thou art my Lord? And he said: 'Thou art not my lord, for I do not know
#
# BLEU Score: 0.0742
#
# Sonnet 18:
# Original:
# Shall I compare thee to a summer's day?
#   Thou art more lovely and more temperate:
#   Rough winds do shake the darling buds of May,
#   And summer's lease hath all too short a date:
#   Sometime too hot the eye of heaven shines,
#   And often is his gold complexion dimm'd;
#   And every fair from fair sometime declines,
#   By chance or nature's changing course untrimm'd;
#   But thy eternal summer shall not fade
#   Nor lose possession of that fair thou owest;
#   Nor shall Death brag thou wander'st in his shade,
#   When in eternal lines to time thou growest:
#   So long as men can breathe or eyes can see,
#   So long lives this and this gives life to thee.
#
# Generated:
# Shall I compare thee to a summer's day?
#
#   And I will not be able to see thee,
#   . . .
#    (He says, "I will be unable to look at thee.")
#   , and he says to the woman, I am not able, but I shall be.
#   - The woman says: "You are not a man, are you?"
#   : I do not know, for I have not seen thee. (She says) "Yes, you are a woman."
#   "I am a wife, a mother, an aunt, my sister, the brother of my father, all of them." (The woman)
#   The man says "A man is a husband, is he not?" (he says), "No, he is not." The man replies, (to the man) I know not what I say, nor what he does. The wife says (she says): "What do you mean by that?" The husband replies: (
#
# BLEU Score: 0.0593
#
# Sonnet 19:
# Original:
# Devouring Time, blunt thou the lion's paws,
#   And make the earth devour her own sweet brood;
#   Pluck the keen teeth from the fierce tiger's jaws,
#   And burn the long-lived phoenix in her blood;
#   Make glad and sorry seasons as thou fleets,
#   And do whate'er thou wilt, swift-footed Time,
#   To the wide world and all her fading sweets;
#   But I forbid thee one most heinous crime:
#   O, carve not with thy hours my love's fair brow,
#   Nor draw no lines there with thine antique pen;
#   Him in thy course untainted do allow
#   For beauty's pattern to succeeding men.
#   Yet, do thy worst, old Time: despite thy wrong,
#   My love shall in my verse ever live young.
#
# Generated:
# Devouring Time, blunt thou the lion's paws, and thou shalt be a lion.
#
#   The lion is a great beast, but it is not a beast of burden. It is the beast that is to be carried away. The lion, however, is an animal of great strength, which is of the greatest strength. And the great lion has the power to carry away the lions. But the mighty lion does not carry the beasts away, for he is in the midst of them. For the king of kings is like a mighty beast. He is strong, strong in his strength and strong with his power. So the King of Kings is called the Lion of War.
#
# BLEU Score: 0.0639
#
# Sonnet 20:
# Original:
# A woman's face with Nature's own hand painted
#   Hast thou, the master-mistress of my passion;
#   A woman's gentle heart, but not acquainted
#   With shifting change, as is false women's fashion;
#   An eye more bright than theirs, less false in rolling,
#   Gilding the object whereupon it gazeth;
#   A man in hue, all 'hues' in his controlling,
#   Much steals men's eyes and women's souls amazeth.
#   And for a woman wert thou first created;
#   Till Nature, as she wrought thee, fell a-doting,
#   And by addition me of thee defeated,
#   By adding one thing to my purpose nothing.
#   But since she prick'd thee out for women's pleasure,
#   Mine be thy love and thy love's use their treasure.
#
# Generated:
# A woman's face with Nature's own hand painted on it.
#
#   The woman was wearing a black dress with a white collar and a blue skirt. She was holding a small bag of flowers. The woman had a large, white flower in her hand. Her face was covered with flowers and her eyes were covered in flowers, and she was smiling. It was a beautiful flower. A beautiful, beautiful woman. I was very happy. And I felt very good. But I didn't feel good about it, because I thought that I would be able to do something about this. So I went to the doctor. He said that he would give me a test. That's when I said, "I don't know what to think about that." And he said to me, I don. "You don? You don?" I told him, no. Then he told me that if I did something, he wouldn't give it to you. Because I had no idea what I wanted to
#
# BLEU Score: 0.0529
#
# Average BLEU: 0.0591

# %%
print("=== Final Comparison: Original vs. Generated Sonnets ===")
for i, (original, generated, score) in enumerate(zip(original_sonnets, generated_sonnets, bleu_scores), 1):
    print(f"\nSonnet {i}:")
    print("Original:")
    print(original.replace('\n', '\n  '))
    print("\nGenerated:")
    print(generated.replace('\n', '\n  '))
    print(f"\nBLEU Score: {score:.4f}")

print(f"\nAverage BLEU: {sum(bleu_scores) / len(bleu_scores) if bleu_scores else 0:.4f}")
